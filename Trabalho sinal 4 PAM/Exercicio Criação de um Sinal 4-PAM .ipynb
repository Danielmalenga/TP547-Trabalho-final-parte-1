# %% [markdown]
# Este código realiza a modulação de um sinal 4-PAM, onde é feita a comparação dos sinais. O mesmo pode ser utilizado em demonstração e análise, desempenho de Sinais em comunicação de sinais digitais, processamento de sinais, como também em projetos de sistemas de comunicação de sinais.

# %%
import numpy as np
import matplotlib.pyplot as plt


N = 2000  # amostragem
p = 30
t = np.linspace(-p,p,N,endpoint=False)




# Portadora
portadora = np.repeat(data,200)

# sinal de dados aleatórios (bits)
data=(np.random.rand(10)>0.5)

# gera a mensagem aleatória (valores entre 0 e 3)
mensagem = np.random.randint(0, 4, N)
amplitude = [-3, -1, 1, 3]
sinal_mensagem = np.array([amplitude[i] for i in mensagem])


# sinal modulado PAM
pam = sinal_mensagem*portadora


# Plotagem do Gráfico do sinal de mensagem
plt.figure(figsize=(15, 10))
plt.subplot(2, 1, 1)
plt.plot(t, sinal_mensagem)
plt.title('Sinal de Mensagem')
plt.xlabel('Tempo (s)')
plt.ylabel('Amplitude')


# Plotagem do Gráfico sinal modulado (4-PAM)
plt.subplot(2, 1, 2)
plt.title('Sinal Modulado (4-PAM)')
plt.plot(t, pam)
plt.xlabel('Tempo (s)')
plt.ylabel('Amplitude')

plt.tight_layout()
plt.show()
